# %% [markdown]
# # 0. Importing Necessary Packages

# %%
# %set_env PATH=/root/anaconda3/bin:/root/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/root/.fzf./bin
# python vscode kernel restart 이후에도 base(python 3.7.6) 정상 작동하는 역할
# Out:
# env: PATH=/root/anaconda3/bin:/root/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/root/.fzf./bin

# %%
# Printing the versions of packages
from importlib_metadata import version
for pkg in ['numpy', 'matplotlib', 'astropy', 'pandas']:
    print(pkg+": ver "+version(pkg))
# Out:
# numpy: ver 1.21.5
# matplotlib: ver 3.5.2
# astropy: ver 5.1
# pandas: ver 1.4.4

# %%
# matplotlib backend
# %matplotlib notebook

# importing necessary modules
import numpy as np
import glob, os
from matplotlib import pyplot as plt
from astropy.io import fits
import pandas as pd
#from acstools import acszpt
#from reproject import reproject_interp

# %%
plt.rcParams.update({'font.size': 25})
plt.rcParams.update({'font.weight': 'normal'})

plt.rcParams.update({'xtick.direction': 'in'})
plt.rcParams.update({'ytick.direction': 'in'})
plt.rcParams.update({'xtick.major.size': 10})
plt.rcParams.update({'xtick.minor.size': 6})
plt.rcParams.update({'ytick.major.size': 10})
plt.rcParams.update({'ytick.minor.size': 6})
plt.rcParams.update({'xtick.major.width': 1.6})
plt.rcParams.update({'xtick.minor.width': 1.6})
plt.rcParams.update({'ytick.major.width': 1.6})
plt.rcParams.update({'ytick.minor.width': 1.6})

plt.rcParams.update({'lines.linewidth': 2})
plt.rcParams.update({'axes.linewidth': 1.6})
plt.rcParams.update({'axes.labelpad': 4})
plt.rcParams.update({'xtick.major.pad': 7})
plt.rcParams.update({'image.origin':'lower'})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 1. Writing Input Files

# %% [markdown]
# ## 1) Image list

# %% [markdown]
# 105 150 200 중 105 150 먼저 쓰기 / 105가 ref

# %%
dir_img = "../../../img/align-image/" #"../FWHM/SExtractor/img_edit/"
band = ["F150W", "F200W"]
imglist_sub = sorted(glob.glob(dir_img+"*.fits"))
imglist_sub
imglist = [imglist_sub[2], imglist_sub[4]]
imglist
# Out:
# ['../../../img/align-image/jw01345-o002_t022_nircam_clear_f150w_aligned.fits',
#  '../../../img/align-image/jw01345-o002_t022_nircam_clear_f200w_aligned.fits']

# %% [markdown]
# ## 2) Configuration file

# %%
config_name = "config.txt"
os.system("sex -dd > "+config_name)
# Out:
# 0

# %% [markdown]
# ## 3) Output parameter file

# %%
param_name = "output.param"
f = open(param_name, "w")
f.write("X_IMAGE\n")    # Object position along x [pixel]
f.write("Y_IMAGE\n")    # Object position along y [pixel]
f.write("NUMBER\n")    # Object number
f.write("MAG_AUTO\n")    # Kron-like elliptical aperture magnitude [mag]
f.write("MAGERR_AUTO\n")    # RMS error for MAG_AUTO    [mag]
f.write("MAG_ISO\n") # Isophotal Magnitude
f.write("MAGERR_ISO\n") # Isophotal Magnitude Error
f.write("MAG_ISOCOR\n")
f.write("MAGERR_ISOCOR\n")
f.write("KRON_RADIUS\n")    # Kron apertures in units of A or B
f.write("BACKGROUND\n")    # Background at centroid position
f.write("ALPHA_J2000\n")    # Right ascension of object center (J2000)
f.write("DELTA_J2000\n")    # Declination of object center (J2000)
f.write("A_IMAGE\n")    # Along major axis
f.write("B_IMAGE\n")    # Along minor axis
f.write("THETA_IMAGE\n")    # Position angle
f.write("MU_MAX\n")    # Peak surface brightness above background
f.write("FLAGS\n")    # Extraction flags
f.write("FWHM_IMAGE\n")    # FWHM assuming a gaussian core
f.write("FLUX_RADIUS\n")    # Half-light radii
f.write("CLASS_STAR\n")    # Star/Galaxy classifier output
f.close()

# %% [markdown]
# ## 4) Determining input parameters

# %%
hdr_1 = fits.getheader(imglist[0], ext=1)
hdr_2 = fits.getheader(imglist[1], ext=1)

# %% [markdown]
# reference for zp in JWST docs <br>
# https://jwst-docs.stsci.edu/jwst-near-infrared-camera/nircam-performance/nircam-absolute-flux-calibration-and-zeropoints

# %% [markdown]
# use AB mag

# %% [markdown]
# ### 4-a) zeropoint calculation from imageheader value

# %%
# band = ["F105W", "F160W"]
cat_name = ["{}.cat".format(band[0]), "{}.cat".format(band[1])]
detect_minarea = 9  # DETECT_MINAREA = 5 (default)
detect_thresh = 0.3  #1이었음 # DETECT_THRESH = 1.5 (default)
saturated = 100.0  # SATUR_LEVEL = 100.0 (depending on the image!)
mag0 = [-6.10-2.5*np.log10(hdr_1['PIXAR_SR']),
        -6.10-2.5*np.log10(hdr_2['PIXAR_SR'])]
# mag0 = [26.268, 25.946]
# egain = [hdr_1['CCDGAIN']*hdr_1['EXPTIME'], hdr_2['CCDGAIN']*hdr_2['EXPTIME']]
# GAIN (effective gain) = gain*exptime (for c/s image) --> this parameter only affects the magnitude error value!
pixel_scale = 0.03  # arcsec/pixel
fwhm = [0.08, 0.08] #이번에 내가 쓰는 reduce img는 0.06arcsec/pixel   # For HST images, seeing FWHMs are typically 3 pixels (~ 0.09 arcsec).
# However, you can directly measure the FWHM value in your image using imexamine or etc.,
# because the FWHM value can also vary with image quality.
back_size = [64, 64]  # BACK_SIZE = 64 (default) --> 32 (revised)
# Smaller BACK_SIZE --> Can subtract more local background --> Can detect more sources
back_filtersize = [3, 3]

checkimg = ["{}_aper.fits".format(band[0]), "{}_aper.fits".format(band[1])]  # CHECKIMAGE_NAME (apertures)
refimg = imglist[0]


deblend_nthresh = [64, 64]
debelnd_mincont = [0.0001, 0.0001]

backphoto_type = "LOCAL"
backphoto_thick = 24

weight_image = ["../../../img/align-image/jw01345-o002_t022_nircam_clear_f150w_aligned.fits[2]","../../../img/align-image/jw01345-o002_t022_nircam_clear_f200w_aligned.fits[2]"]
refimg_rmsmap = weight_image[0]
weight_type = "MAP_WEIGHT" #MAP_RMS, MAP_WEIGHT
weight_gain = "Y"

filtering = "Y"
filter_name = "../config/default.conv"
# filter_thresh = [0.5, 1.0]

# %% [markdown]
# ### 4-b) PHOTFLAM / PHOTPLAM calculation by ACS zeropoint calculation system

# %%
''' 
dates = ['2011-07-16']
queries1 = []
queries2 = []
for date in dates:
    q1 = acszpt.Query(date=date, detector='WFC', filt='F606W')
    zpt_table = q1.fetch()
    # Each object has a zpt_table attribute, so we save the instance
    queries1.append(q1)
for date in dates:
    q2 = acszpt.Query(date=date, detector='WFC', filt='F814W')
    zpt_table = q2.fetch()
    # Each object has a zpt_table attribute, so we save the instance
    queries2.append(q2)


hdr_1["PHOTFLAM"]= q1.zpt_table['PHOTFLAM'][0].value
hdr_1["PHOTPLAM"]= q1.zpt_table['PHOTPLAM'][0].value
hdr_2["PHOTFLAM"]= q2.zpt_table['PHOTFLAM'][0].value
hdr_2["PHOTPLAM"]= q2.zpt_table['PHOTPLAM'][0].value


'''
# Out:
# ' \ndates = [\'2011-07-16\']\nqueries1 = []\nqueries2 = []\nfor date in dates:\n    q1 = acszpt.Query(date=date, detector=\'WFC\', filt=\'F606W\')\n    zpt_table = q1.fetch()\n    # Each object has a zpt_table attribute, so we save the instance\n    queries1.append(q1)\nfor date in dates:\n    q2 = acszpt.Query(date=date, detector=\'WFC\', filt=\'F814W\')\n    zpt_table = q2.fetch()\n    # Each object has a zpt_table attribute, so we save the instance\n    queries2.append(q2)\n\n\nhdr_1["PHOTFLAM"]= q1.zpt_table[\'PHOTFLAM\'][0].value\nhdr_1["PHOTPLAM"]= q1.zpt_table[\'PHOTPLAM\'][0].value\nhdr_2["PHOTFLAM"]= q2.zpt_table[\'PHOTFLAM\'][0].value\nhdr_2["PHOTPLAM"]= q2.zpt_table[\'PHOTPLAM\'][0].value\n\n\n'

# %% [markdown]
# ## 5) Shell script for SExtractor photometry

# %%
scr_name = "sephot.sh"
f = open(scr_name, "w")
for i in np.arange(len(band)):
        
    # Reference image 
    if (imglist[i] == refimg):
        txt = "sex "+imglist[i]+"[1]"+" -c config.txt -CATALOG_NAME "+cat_name[i]+" -PARAMETERS_NAME output.param "
        txt += f"-WEIGHT_GAIN {weight_gain:s} -WEIGHT_IMAGE {weight_image[i]:s} -WEIGHT_TYPE {weight_type:s} "

    # Non-reference image
    else:
        txt = "sex "+refimg+"[1]"+","+imglist[i]+"[1]"+" -c config.txt -CATALOG_NAME "+cat_name[i]+" -PARAMETERS_NAME output.param "
        txt += f"-WEIGHT_GAIN {weight_gain:s} -WEIGHT_IMAGE {refimg_rmsmap:s},{weight_image[i]:s} -WEIGHT_TYPE {weight_type:s} "

    #==== new added param
    txt += f"-BACK_FILTERSIZE {back_filtersize[i]:d} -DEBLEND_NTHRESH {deblend_nthresh[i]:d} -DEBLEND_MINCONT {debelnd_mincont[i]:.5f} -BACKPHOTO_TYPE {backphoto_type:s} -BACKPHOTO_THICK {backphoto_thick:d} "
    txt += f"-FILTER {filtering:s} -FILTER_NAME {filter_name:s} " #filtering part 제대로 적용안되는 듯 하면서 여전히 -FILTER_THRESH {filter_thresh[0]:.4f},{filter_thresh[1]:.4f} "
    #==== origin param
    txt += f"-DETECT_MINAREA {detect_minarea:d} -DETECT_THRESH {detect_thresh:.1f} "
    txt += f"-SATUR_LEVEL {saturated:.1f} "#txt += f"-FILTER_NAME /usr/share/sextractor/default.conv -SATUR_LEVEL {saturated:.1f} "
    txt += f"-MAG_ZEROPOINT {mag0[i]:.4f} -PIXEL_SCALE {pixel_scale:.2f} " #-GAIN {egain[i]:.2f} "
    txt += f"-SEEING_FWHM {fwhm[i]:.2f} -STARNNW_NAME ../config/default.nnw -BACK_SIZE {back_size[i]:d} "
    txt += "-CHECKIMAGE_TYPE APERTURES -CHECKIMAGE_NAME "+checkimg[i] # -CHECKIMAGE_TYPE APERTURES 
    txt += "\n"
    
    f.write(txt)
    
    
f.close()

# %% [markdown]
# # 2. Running SExtractor

# %% [markdown]
# use alignimage for dual-mode (same frame size need)

# %%
os.system("sh sephot.sh")
# Run this and see the terminal where the Jupyter Notebook is open!
# Out:
# >
# ----- SExtractor 2.25.0 started on 2023-02-15 at 11:41:36 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for jw01345-o002_t022_nircam_clear_f150w_aligned.fits
# ----- Measuring from: jw01345-o002_t022_nircam_clear_f150w_aligned.fits [1/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f150w_aligned.fits
# ----- Weighting from: jw01345-o002_t022_nircam_clear_f150w_aligned.fits [2/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 0.197915   RMS: 0.00761708 / Threshold: 0.00228512
# > Scanning image
# > Line:   25  Objects:      759 detected /        0 sextracted
# > Line:   50  Objects:     2166 detected /        0 sextracted
# > Line:   75  Objects:     3730 detected /        0 sextracted
# > Line:  100  Objects:     5671 detected /     1165 sextracted
# > Line:  125  Objects:     9733 detected /     4365 sextracted
# > Line:  150  Objects:    12496 detected /     6322 sextracted
# > Line:  175  Objects:    14723 detected /     7935 sextracted
# > Line:  200  Objects:    17392 detected /     9857 sextracted
# > Line:  225  Objects:    19604 detected /    11417 sextracted
# > Line:  250  Objects:    22069 detected /    13231 sextracted
# > Line:  275  Objects:    24862 detected /    15268 sextracted
# > Line:  300  Objects:    27122 detected /    16896 sextracted
# > Line:  325  Objects:    30353 detected /    19329 sextracted
# > Line:  350  Objects:    33207 detected /    21417 sextracted
# > Line:  375  Objects:    35541 detected /    23100 sextracted
# > Line:  400  Objects:    38072 detected /    24946 sextracted
# > Line:  425  Objects:    40447 detected /    26626 sextracted
#
# > WARNING: Pixel stack overflow at position 1732,429
#
# > Line:  450  Objects:    43352 detected /    28822 sextracted
# > Line:  475  Objects:    46382 detected /    31061 sextracted
# > Line:  500  Objects:    49100 detected /    32987 sextracted
# > Line:  525  Objects:    51307 detected /    34559 sextracted
# > Line:  550  Objects:    54251 detected /    36731 sextracted
# > Line:  575  Objects:    57017 detected /    38704 sextracted
# > Line:  600  Objects:    59125 detected /    40227 sextracted
# > Line:  625  Objects:    61816 detected /    42166 sextracted
# > Line:  650  Objects:    65471 detected /    44897 sextracted
# > Line:  675  Objects:    68102 detected /    46865 sextracted
# > Line:  700  Objects:    71323 detected /    49193 sextracted
# > Line:  725  Objects:    74179 detected /    51198 sextracted
# > Line:  750  Objects:    76831 detected /    53157 sextracted
#
# > WARNING: Pixel stack overflow at position 5979,767
#
# > Line:  775  Objects:    79692 detected /    55279 sextracted
# > Line:  800  Objects:    81609 detected /    56692 sextracted
# > Line:  825  Objects:    84530 detected /    58851 sextracted
# > Line:  850  Objects:    88072 detected /    61534 sextracted
# > Line:  875  Objects:    91445 detected /    64077 sextracted
# > Line:  900  Objects:    94224 detected /    66069 sextracted
# > Line:  925  Objects:    97197 detected /    68186 sextracted
# > Line:  950  Objects:    99145 detected /    69600 sextracted
# > Line:  975  Objects:   102260 detected /    71879 sextracted
# > Line: 1000  Objects:   104626 detected /    73597 sextracted
# > Line: 1025  Objects:   107234 detected /    75493 sextracted
# > Line: 1050  Objects:   111316 detected /    78647 sextracted
# > Line: 1075  Objects:   113948 detected /    80514 sextracted
# > Line: 1100  Objects:   116513 detected /    82346 sextracted
# > Line: 1125  Objects:   118924 detected /    84099 sextracted
# > Line: 1150  Objects:   122216 detected /    86629 sextracted
# > Line: 1175  Objects:   125251 detected /    88918 sextracted
# > Line: 1200  Objects:   129023 detected /    91790 sextracted
# > Line: 1225  Objects:   132054 detected /    94001 sextracted
# > Line: 1250  Objects:   135093 detected /    96239 sextracted
# > Line: 1275  Objects:   137905 detected /    98279 sextracted
# > Line: 1300  Objects:   140985 detected /   100538 sextracted
# > Line: 1325  Objects:   143802 detected /   102622 sextracted
# > Line: 1350  Objects:   147473 detected /   105501 sextracted
# > Line: 1375  Objects:   149730 detected /   107168 sextracted
# > Line: 1400  Objects:   152816 detected /   109402 sextracted
# > Line: 1425  Objects:   156066 detected /   111753 sextracted
# > Line: 1450  Objects:   158236 detected /   113296 sextracted
# > Line: 1475  Objects:   161123 detected /   115513 sextracted
# > Line: 1500  Objects:   164007 detected /   117694 sextracted
# > Line: 1525  Objects:   167558 detected /   120410 sextracted
# > Line: 1550  Objects:   170574 detected /   122679 sextracted
# > Line: 1575  Objects:   173527 detected /   124883 sextracted
# > Line: 1600  Objects:   176550 detected /   127141 sextracted
# > Line: 1625  Objects:   179821 detected /   129530 sextracted
# > Line: 1650  Objects:   182378 detected /   131409 sextracted
# > Line: 1675  Objects:   185746 detected /   133932 sextracted
# > Line: 1700  Objects:   189401 detected /   136698 sextracted
# > Line: 1725  Objects:   192690 detected /   139122 sextracted
# > Line: 1750  Objects:   195579 detected /   141195 sextracted
# > Line: 1775  Objects:   198511 detected /   143273 sextracted
# > Line: 1800  Objects:   201364 detected /   145372 sextracted
# > Line: 1825  Objects:   203757 detected /   147102 sextracted
# > Line: 1850  Objects:   206265 detected /   148918 sextracted
# > Line: 1875  Objects:   208717 detected /   150678 sextracted
# > Line: 1900  Objects:   211235 detected /   152511 sextracted
# > Line: 1925  Objects:   214944 detected /   155399 sextracted
# > Line: 1950  Objects:   217469 detected /   157264 sextracted
# > Line: 1975  Objects:   221596 detected /   160459 sextracted
# > Line: 2000  Objects:   223734 detected /   162010 sextracted
# > Line: 2025  Objects:   226394 detected /   163937 sextracted
# > Line: 2050  Objects:   229039 detected /   165906 sextracted
# > Line: 2075  Objects:   231671 detected /   167843 sextracted
# > Line: 2100  Objects:   234454 detected /   170078 sextracted
# > Line: 2125  Objects:   236856 detected /   171980 sextracted
# > Line: 2150  Objects:   238919 detected /   173483 sextracted
# > Line: 2175  Objects:   241035 detected /   175016 sextracted
# > Line: 2200  Objects:   244002 detected /   177312 sextracted
# > Line: 2225  Objects:   245652 detected /   178565 sextracted
# > Line: 2250  Objects:   246591 detected /   179266 sextracted
# > Line: 2275  Objects:   248195 detected /   180423 sextracted
# > Line: 2300  Objects:   250993 detected /   182396 sextracted
# > Line: 2325  Objects:   254985 detected /   185407 sextracted
# > Line: 2350  Objects:   258614 detected /   188148 sextracted
# > Line: 2375  Objects:   261321 detected /   190084 sextracted
# > Line: 2400  Objects:   264534 detected /   192397 sextracted
# > Line: 2425  Objects:   267298 detected /   194341 sextracted
# > Line: 2450  Objects:   270096 detected /   196288 sextracted
# > Line: 2475  Objects:   273703 detected /   198876 sextracted
# > Line: 2500  Objects:   276548 detected /   200838 sextracted
# > Line: 2525  Objects:   279608 detected /   203115 sextracted
# > Line: 2550  Objects:   282470 detected /   205212 sextracted
# > Line: 2575  Objects:   285347 detected /   207372 sextracted
# > Line: 2600  Objects:   288646 detected /   209873 sextracted
# > Line: 2625  Objects:   291280 detected /   211756 sextracted
# > Line: 2650  Objects:   294379 detected /   213974 sextracted
# > Line: 2675  Objects:   296294 detected /   215286 sextracted
# > Line: 2700  Objects:   300005 detected /   218135 sextracted
# > Line: 2725  Objects:   303347 detected /   220595 sextracted
# > Line: 2750  Objects:   305936 detected /   222433 sextracted
# > Line: 2775  Objects:   309025 detected /   224643 sextracted
# > Line: 2800  Objects:   312383 detected /   227068 sextracted
# > Line: 2825  Objects:   315623 detected /   229425 sextracted
# > Line: 2850  Objects:   318327 detected /   231366 sextracted
# > Line: 2875  Objects:   320555 detected /   232892 sextracted
# > Line: 2900  Objects:   323379 detected /   234940 sextracted
# > Line: 2925  Objects:   326380 detected /   237150 sextracted
# > Line: 2950  Objects:   329945 detected /   239757 sextracted
# > Line: 2975  Objects:   332866 detected /   241750 sextracted
# > Line: 3000  Objects:   336153 detected /   244065 sextracted
# > Line: 3025  Objects:   339660 detected /   246624 sextracted
# > Line: 3050  Objects:   342222 detected /   248444 sextracted
# > Line: 3075  Objects:   344883 detected /   250357 sextracted
# > Line: 3100  Objects:   348248 detected /   252799 sextracted
# > Line: 3125  Objects:   350903 detected /   254711 sextracted
# > Line: 3150  Objects:   353107 detected /   256250 sextracted
# > Line: 3175  Objects:   356556 detected /   258755 sextracted
# > Line: 3200  Objects:   359744 detected /   261046 sextracted
# > Line: 3225  Objects:   362292 detected /   262848 sextracted
# > Line: 3250  Objects:   364572 detected /   264493 sextracted
# > Line: 3275  Objects:   367525 detected /   266669 sextracted
# > Line: 3300  Objects:   370066 detected /   268509 sextracted
# > Line: 3325  Objects:   372434 detected /   270235 sextracted
# > Line: 3350  Objects:   375115 detected /   272159 sextracted
# > Line: 3375  Objects:   377238 detected /   273667 sextracted
# > Line: 3400  Objects:   380390 detected /   276019 sextracted
# > Line: 3425  Objects:   383083 detected /   278052 sextracted
# > Line: 3450  Objects:   385326 detected /   279674 sextracted
# > Line: 3475  Objects:   388898 detected /   282366 sextracted
# > Line: 3500  Objects:   391742 detected /   284400 sextracted
# > Line: 3525  Objects:   394214 detected /   286140 sextracted
# > Line: 3550  Objects:   396958 detected /   288122 sextracted
# > Line: 3575  Objects:   399813 detected /   290101 sextracted
# > Line: 3600  Objects:   403036 detected /   292470 sextracted
# > Line: 3625  Objects:   405512 detected /   294211 sextracted
# > Line: 3650  Objects:   407717 detected /   295829 sextracted
# > Line: 3675  Objects:   410829 detected /   298149 sextracted
# > Line: 3700  Objects:   413635 detected /   300172 sextracted
# > Line: 3725  Objects:   416426 detected /   302170 sextracted
# > Line: 3750  Objects:   419403 detected /   304266 sextracted
# > Line: 3775  Objects:   422702 detected /   306694 sextracted
# > Line: 3800  Objects:   425217 detected /   308451 sextracted
# > Line: 3825  Objects:   428517 detected /   310816 sextracted
# > Line: 3850  Objects:   431569 detected /   313000 sextracted
# > Line: 3875  Objects:   434271 detected /   314946 sextracted
# > Line: 3900  Objects:   436964 detected /   316850 sextracted
# > Line: 3925  Objects:   439891 detected /   318946 sextracted
# > Line: 3950  Objects:   442367 detected /   320694 sextracted
# > Line: 3975  Objects:   445604 detected /   323052 sextracted
# > Line: 4000  Objects:   448138 detected /   324824 sextracted
# > Line: 4025  Objects:   450905 detected /   326802 sextracted
# > Line: 4050  Objects:   453610 detected /   328750 sextracted
# > Line: 4075  Objects:   456567 detected /   330906 sextracted
# > Line: 4100  Objects:   458955 detected /   332671 sextracted
# > Line: 4125  Objects:   462315 detected /   335139 sextracted
# > Line: 4150  Objects:   464219 detected /   336517 sextracted
# > Line: 4175  Objects:   467403 detected /   338808 sextracted
# > Line: 4200  Objects:   469900 detected /   340577 sextracted
# > Line: 4225  Objects:   472438 detected /   342481 sextracted
# > Line: 4250  Objects:   474991 detected /   344375 sextracted
# > Line: 4275  Objects:   478220 detected /   346992 sextracted
# > Line: 4300  Objects:   480138 detected /   348455 sextracted
# > Line: 4325  Objects:   481757 detected /   349644 sextracted
# > Line: 4350  Objects:   483366 detected /   350854 sextracted
# > Line: 4375  Objects:   484170 detected /   351499 sextracted
# > Line: 4388  Objects:   484234 detected /   351600 sextracted
# > Line: 4388  Objects:   484234 detected /   352000 sextracted
# > Line: 4388  Objects:   484234 detected /   352400 sextracted
# > Line: 4388  Objects:   484234 detected /   352800 sextracted
# > Line: 4388  Objects:   484234 detected /   353200 sextracted
# > Line: 4388  Objects:   484234 detected /   353600 sextracted
# > Line: 4388  Objects:   484234 detected /   354000 sextracted
# > Line: 4388  Objects:   484234 detected /   354400 sextracted
#       Objects: detected 484234   / sextracted 354549
#
# > Closing files
# >
# > All done (in 169.9 s: 25.8 lines/s , 2086.8 detections/s)
# >
# ----- SExtractor 2.25.0 started on 2023-02-15 at 11:44:26 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for jw01345-o002_t022_nircam_clear_f150w_aligned.fits
# ----- Detecting from: jw01345-o002_t022_nircam_clear_f150w_aligned.fits [1/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f200w_aligned.fits
# ----- Measuring from: jw01345-o002_t022_nircam_clear_f200w_aligned.fits [1/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f200w_aligned.fits
# ----- Weighting from: jw01345-o002_t022_nircam_clear_f200w_aligned.fits [2/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f150w_aligned.fits
# ----- Weighting from: jw01345-o002_t022_nircam_clear_f150w_aligned.fits [2/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# Measurement image:> Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M)   Background: 0.167512   RMS: 0.00582896 / Threshold: 0.00874344
# Detection image: > Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (D)   Background: 0.197915   RMS: 0.00761708 / Threshold: 0.00228512
# > Scanning image
# > Line:   25  Objects:      759 detected /        0 sextracted
# > Line:   50  Objects:     2166 detected /        0 sextracted
# > Line:   75  Objects:     3730 detected /        0 sextracted
# > Line:  100  Objects:     5671 detected /     1165 sextracted
# > Line:  125  Objects:     9733 detected /     4365 sextracted
# > Line:  150  Objects:    12496 detected /     6322 sextracted
# > Line:  175  Objects:    14723 detected /     7935 sextracted
# > Line:  200  Objects:    17392 detected /     9857 sextracted
# > Line:  225  Objects:    19604 detected /    11417 sextracted
# > Line:  250  Objects:    22069 detected /    13231 sextracted
# > Line:  275  Objects:    24862 detected /    15268 sextracted
# > Line:  300  Objects:    27122 detected /    16896 sextracted
# > Line:  325  Objects:    30353 detected /    19329 sextracted
# > Line:  350  Objects:    33207 detected /    21417 sextracted
# > Line:  375  Objects:    35541 detected /    23100 sextracted
# > Line:  400  Objects:    38072 detected /    24946 sextracted
# > Line:  425  Objects:    40447 detected /    26626 sextracted
#
# > WARNING: Pixel stack overflow at position 1732,429
#
# > Line:  450  Objects:    43352 detected /    28822 sextracted
# > Line:  475  Objects:    46382 detected /    31061 sextracted
# > Line:  500  Objects:    49100 detected /    32987 sextracted
# > Line:  525  Objects:    51307 detected /    34559 sextracted
# > Line:  550  Objects:    54251 detected /    36731 sextracted
# > Line:  575  Objects:    57017 detected /    38704 sextracted
# > Line:  600  Objects:    59125 detected /    40227 sextracted
# > Line:  625  Objects:    61816 detected /    42166 sextracted
# > Line:  650  Objects:    65471 detected /    44897 sextracted
# > Line:  675  Objects:    68102 detected /    46865 sextracted
# > Line:  700  Objects:    71323 detected /    49193 sextracted
# > Line:  725  Objects:    74179 detected /    51198 sextracted
# > Line:  750  Objects:    76831 detected /    53157 sextracted
#
# > WARNING: Pixel stack overflow at position 5979,767
#
# > Line:  775  Objects:    79692 detected /    55279 sextracted
# > Line:  800  Objects:    81609 detected /    56692 sextracted
# > Line:  825  Objects:    84530 detected /    58851 sextracted
# > Line:  850  Objects:    88072 detected /    61534 sextracted
# > Line:  875  Objects:    91445 detected /    64077 sextracted
# > Line:  900  Objects:    94224 detected /    66069 sextracted
# > Line:  925  Objects:    97197 detected /    68186 sextracted
# > Line:  950  Objects:    99145 detected /    69600 sextracted
# > Line:  975  Objects:   102260 detected /    71879 sextracted
# > Line: 1000  Objects:   104626 detected /    73597 sextracted
# > Line: 1025  Objects:   107234 detected /    75493 sextracted
# > Line: 1050  Objects:   111316 detected /    78647 sextracted
# > Line: 1075  Objects:   113948 detected /    80514 sextracted
# > Line: 1100  Objects:   116513 detected /    82346 sextracted
# > Line: 1125  Objects:   118924 detected /    84099 sextracted
# > Line: 1150  Objects:   122216 detected /    86629 sextracted
# > Line: 1175  Objects:   125251 detected /    88918 sextracted
# > Line: 1200  Objects:   129023 detected /    91790 sextracted
# > Line: 1225  Objects:   132054 detected /    94001 sextracted
# > Line: 1250  Objects:   135093 detected /    96239 sextracted
# > Line: 1275  Objects:   137905 detected /    98279 sextracted
# > Line: 1300  Objects:   140985 detected /   100538 sextracted
# > Line: 1325  Objects:   143802 detected /   102622 sextracted
# > Line: 1350  Objects:   147473 detected /   105501 sextracted
# > Line: 1375  Objects:   149730 detected /   107168 sextracted
# > Line: 1400  Objects:   152816 detected /   109402 sextracted
# > Line: 1425  Objects:   156066 detected /   111753 sextracted
# > Line: 1450  Objects:   158236 detected /   113296 sextracted
# > Line: 1475  Objects:   161123 detected /   115513 sextracted
# > Line: 1500  Objects:   164007 detected /   117694 sextracted
# > Line: 1525  Objects:   167558 detected /   120410 sextracted
# > Line: 1550  Objects:   170574 detected /   122679 sextracted
# > Line: 1575  Objects:   173527 detected /   124883 sextracted
# > Line: 1600  Objects:   176550 detected /   127141 sextracted
# > Line: 1625  Objects:   179821 detected /   129530 sextracted
# > Line: 1650  Objects:   182378 detected /   131409 sextracted
# > Line: 1675  Objects:   185746 detected /   133932 sextracted
# > Line: 1700  Objects:   189401 detected /   136698 sextracted
# > Line: 1725  Objects:   192690 detected /   139122 sextracted
# > Line: 1750  Objects:   195579 detected /   141195 sextracted
# > Line: 1775  Objects:   198511 detected /   143273 sextracted
# > Line: 1800  Objects:   201364 detected /   145372 sextracted
# > Line: 1825  Objects:   203757 detected /   147102 sextracted
# > Line: 1850  Objects:   206265 detected /   148918 sextracted
# > Line: 1875  Objects:   208717 detected /   150678 sextracted
# > Line: 1900  Objects:   211235 detected /   152511 sextracted
# > Line: 1925  Objects:   214944 detected /   155399 sextracted
# > Line: 1950  Objects:   217469 detected /   157264 sextracted
# > Line: 1975  Objects:   221596 detected /   160459 sextracted
# > Line: 2000  Objects:   223734 detected /   162010 sextracted
# > Line: 2025  Objects:   226394 detected /   163937 sextracted
# > Line: 2050  Objects:   229039 detected /   165906 sextracted
# > Line: 2075  Objects:   231671 detected /   167843 sextracted
# > Line: 2100  Objects:   234454 detected /   170078 sextracted
# > Line: 2125  Objects:   236856 detected /   171980 sextracted
# > Line: 2150  Objects:   238919 detected /   173483 sextracted
# > Line: 2175  Objects:   241035 detected /   175016 sextracted
# > Line: 2200  Objects:   244002 detected /   177312 sextracted
# > Line: 2225  Objects:   245652 detected /   178565 sextracted
# > Line: 2250  Objects:   246591 detected /   179266 sextracted
# > Line: 2275  Objects:   248195 detected /   180423 sextracted
# > Line: 2300  Objects:   250993 detected /   182396 sextracted
# > Line: 2325  Objects:   254985 detected /   185407 sextracted
# > Line: 2350  Objects:   258614 detected /   188148 sextracted
# > Line: 2375  Objects:   261321 detected /   190084 sextracted
# > Line: 2400  Objects:   264534 detected /   192397 sextracted
# > Line: 2425  Objects:   267298 detected /   194341 sextracted
# > Line: 2450  Objects:   270096 detected /   196288 sextracted
# > Line: 2475  Objects:   273703 detected /   198876 sextracted
# > Line: 2500  Objects:   276548 detected /   200838 sextracted
# > Line: 2525  Objects:   279608 detected /   203115 sextracted
# > Line: 2550  Objects:   282470 detected /   205212 sextracted
# > Line: 2575  Objects:   285347 detected /   207372 sextracted
# > Line: 2600  Objects:   288646 detected /   209873 sextracted
# > Line: 2625  Objects:   291280 detected /   211756 sextracted
# > Line: 2650  Objects:   294379 detected /   213974 sextracted
# > Line: 2675  Objects:   296294 detected /   215286 sextracted
# > Line: 2700  Objects:   300005 detected /   218135 sextracted
# > Line: 2725  Objects:   303347 detected /   220595 sextracted
# > Line: 2750  Objects:   305936 detected /   222433 sextracted
# > Line: 2775  Objects:   309025 detected /   224643 sextracted
# > Line: 2800  Objects:   312383 detected /   227068 sextracted
# > Line: 2825  Objects:   315623 detected /   229425 sextracted
# > Line: 2850  Objects:   318327 detected /   231366 sextracted
# > Line: 2875  Objects:   320555 detected /   232892 sextracted
# > Line: 2900  Objects:   323379 detected /   234940 sextracted
# > Line: 2925  Objects:   326380 detected /   237150 sextracted
# > Line: 2950  Objects:   329945 detected /   239757 sextracted
# > Line: 2975  Objects:   332866 detected /   241750 sextracted
# > Line: 3000  Objects:   336153 detected /   244065 sextracted
# > Line: 3025  Objects:   339660 detected /   246624 sextracted
# > Line: 3050  Objects:   342222 detected /   248444 sextracted
# > Line: 3075  Objects:   344883 detected /   250357 sextracted
# > Line: 3100  Objects:   348248 detected /   252799 sextracted
# > Line: 3125  Objects:   350903 detected /   254711 sextracted
# > Line: 3150  Objects:   353107 detected /   256250 sextracted
# > Line: 3175  Objects:   356556 detected /   258755 sextracted
# > Line: 3200  Objects:   359744 detected /   261046 sextracted
# > Line: 3225  Objects:   362292 detected /   262848 sextracted
# > Line: 3250  Objects:   364572 detected /   264493 sextracted
# > Line: 3275  Objects:   367525 detected /   266669 sextracted
# > Line: 3300  Objects:   370066 detected /   268509 sextracted
# > Line: 3325  Objects:   372434 detected /   270235 sextracted
# > Line: 3350  Objects:   375115 detected /   272159 sextracted
# > Line: 3375  Objects:   377238 detected /   273667 sextracted
# > Line: 3400  Objects:   380390 detected /   276019 sextracted
# > Line: 3425  Objects:   383083 detected /   278052 sextracted
# > Line: 3450  Objects:   385326 detected /   279674 sextracted
# > Line: 3475  Objects:   388898 detected /   282366 sextracted
# > Line: 3500  Objects:   391742 detected /   284400 sextracted
# > Line: 3525  Objects:   394214 detected /   286140 sextracted
# > Line: 3550  Objects:   396958 detected /   288122 sextracted
# > Line: 3575  Objects:   399813 detected /   290101 sextracted
# > Line: 3600  Objects:   403036 detected /   292470 sextracted
# > Line: 3625  Objects:   405512 detected /   294211 sextracted
# > Line: 3650  Objects:   407717 detected /   295829 sextracted
# > Line: 3675  Objects:   410829 detected /   298149 sextracted
# > Line: 3700  Objects:   413635 detected /   300172 sextracted
# > Line: 3725  Objects:   416426 detected /   302170 sextracted
# > Line: 3750  Objects:   419403 detected /   304266 sextracted
# > Line: 3775  Objects:   422702 detected /   306694 sextracted
# > Line: 3800  Objects:   425217 detected /   308451 sextracted
# > Line: 3825  Objects:   428517 detected /   310816 sextracted
# > Line: 3850  Objects:   431569 detected /   313000 sextracted
# > Line: 3875  Objects:   434271 detected /   314946 sextracted
# > Line: 3900  Objects:   436964 detected /   316850 sextracted
# > Line: 3925  Objects:   439891 detected /   318946 sextracted
# > Line: 3950  Objects:   442367 detected /   320694 sextracted
# > Line: 3975  Objects:   445604 detected /   323052 sextracted
# > Line: 4000  Objects:   448138 detected /   324824 sextracted
# > Line: 4025  Objects:   450905 detected /   326802 sextracted
# > Line: 4050  Objects:   453610 detected /   328750 sextracted
# > Line: 4075  Objects:   456567 detected /   330906 sextracted
# > Line: 4100  Objects:   458955 detected /   332671 sextracted
# > Line: 4125  Objects:   462315 detected /   335139 sextracted
# > Line: 4150  Objects:   464219 detected /   336517 sextracted
# > Line: 4175  Objects:   467403 detected /   338808 sextracted
# > Line: 4200  Objects:   469900 detected /   340577 sextracted
# > Line: 4225  Objects:   472438 detected /   342481 sextracted
# > Line: 4250  Objects:   474991 detected /   344375 sextracted
# > Line: 4275  Objects:   478220 detected /   346992 sextracted
# > Line: 4300  Objects:   480138 detected /   348455 sextracted
# > Line: 4325  Objects:   481757 detected /   349644 sextracted
# > Line: 4350  Objects:   483366 detected /   350854 sextracted
# > Line: 4375  Objects:   484170 detected /   351499 sextracted
# > Line: 4388  Objects:   484234 detected /   351600 sextracted
# > Line: 4388  Objects:   484234 detected /   352000 sextracted
# > Line: 4388  Objects:   484234 detected /   352400 sextracted
# > Line: 4388  Objects:   484234 detected /   352800 sextracted
# > Line: 4388  Objects:   484234 detected /   353200 sextracted
# > Line: 4388  Objects:   484234 detected /   353600 sextracted
# > Line: 4388  Objects:   484234 detected /   354000 sextracted
# > Line: 4388  Objects:   484234 detected /   354400 sextracted
#       Objects: detected 484234   / sextracted 354549
#
# > Closing files
# >
# > All done (in 171.8 s: 25.5 lines/s , 2064.3 detections/s)
# 0

# %% [markdown]
# # 3. Reading the Data

# %%
# exec("dat_{} = np.genfromtxt(cat_name[0], dtype=None, encoding='ascii', names=colnames)".format(band[0]))
# exec("dat_{} = np.genfromtxt(cat_nam"e[1], dtype=None, encoding='ascii', names=colnames)".format(band[1]))
# Code that makes data name containts wave band
colnames = ['x','y','num','mag_auto','magerr_auto','mag_iso','magerr_iso','mag_isocor','magerr_isocor','kron','backgr','ra','dec', 
            'a','b','theta','mu0','flag','fwhm','flxrad','cl']
dat_0 = np.genfromtxt(cat_name[0], dtype=None, encoding='ascii', names=colnames)
dat_1 = np.genfromtxt(cat_name[1], dtype=None, encoding='ascii', names=colnames)

# %%
pd.DataFrame(dat_0).head(5)
# Out:
#            x       y  num  mag_auto  magerr_auto  mag_iso  magerr_iso  \
# 0  1828.4906  1.1879    1   30.4484       0.6765  30.0148      0.2864
# 1  2410.9880  1.0000    2   29.9106       0.3259  30.4040      0.3757
# 2  2506.6572  1.0000    3   30.1325       0.4251  29.9501      0.2706
# 3  2753.9973  1.0000    4   29.9577       0.3409  29.4943      0.2423
# 4  3637.4521  1.5037    5   30.0566       0.4225  30.3230      0.3226
#
#    mag_isocor  magerr_isocor  kron  ...          ra        dec      a      b  \
# 0     29.9155         0.2661  3.50  ...  214.840452  52.905815  2.377  0.390
# 1     30.2913         0.3456  3.50  ...  214.845952  52.909655  2.135  0.263
# 2     29.8624         0.2533  3.50  ...  214.846856  52.910285  3.060  0.223
# 3     29.3773         0.2227  3.50  ...  214.849193  52.911915  1.370  0.505
# 4     30.2289         0.3007  4.27  ...  214.857546  52.917735  1.097  0.487
#
#    theta      mu0  flag  fwhm  flxrad     cl
# 0   0.36  24.3768    25  5.74   1.443  0.599
# 1   0.01  24.6780    27  4.44   8.704  0.623
# 2   0.74  24.2755    27  4.91   3.721  0.586
# 3  -1.82  24.1217    27  4.94   1.543  0.651
# 4   6.66  24.1756    27  4.33   1.112  0.573
#
# [5 rows x 21 columns]

# %%
pd.DataFrame(dat_1).head(5)
# Out:
#            x       y  num  mag_auto  magerr_auto  mag_iso  magerr_iso  \
# 0  1828.4906  1.1879    1   30.3062       0.3533  31.7794       0.798
# 1  2410.9880  1.0000    2   99.0000      99.0000  99.0000      99.000
# 2  2506.6572  1.0000    3   99.0000      99.0000  99.0000      99.000
# 3  2753.9973  1.0000    4   99.0000      99.0000  99.0000      99.000
# 4  3637.4521  1.5037    5   99.0000      99.0000  99.0000      99.000
#
#    mag_isocor  magerr_isocor  kron  ...          ra        dec      a      b  \
# 0     28.5838         0.0875   3.5  ...  214.840553  52.905701  2.377  0.390
# 1     99.0000        99.0000   0.0  ...  214.845980  52.909571  2.135  0.263
# 2     99.0000        99.0000   0.0  ...  214.846872  52.910207  3.060  0.223
# 3     99.0000        99.0000   0.0  ...  214.849177  52.911850  1.370  0.505
# 4     99.0000        99.0000   0.0  ...  214.857419  52.917714  1.097  0.487
#
#    theta      mu0  flag  fwhm  flxrad     cl
# 0   0.36  25.5731    25  0.00   4.733  0.380
# 1   0.01  28.2198    27  0.00   7.965  0.019
# 2   0.74  25.7757    27  0.00   3.165  0.359
# 3  -1.82  24.9791    27  4.94 -57.667  0.530
# 4   6.66  25.4031    27  4.33   0.000  0.397
#
# [5 rows x 21 columns]

# %% [markdown]
# # 5. Plotting the Figures

# %%
# %matplotlib inline

# %% [markdown]
# ### 0) RA/DEC

# %%
fig, axs = plt.subplots(1, 1, figsize=(5,5))
axs.plot(dat_0['ra'], dat_0['dec'], 'o', ms=0.5, label = 'SEx')
axs.set_xlabel("ra")
axs.set_ylabel("Dec")
# change legend markersize
lgnd = axs.legend()
lgnd.legendHandles[0].set_markersize(6)

# %% [markdown]
# ### 1) Mag-MagErr Plot

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,4))
# mag_range = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)

# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax[0].plot(dat_0['mag_isocor'], dat_0['magerr_isocor'], 'o', ms=0.01, label='SEx')
ax[0].set_xlim([12.5, 32])
ax[0].set_ylim([0.0, 1.0])
ax[0].set_xlabel('F150W mag')
ax[0].set_ylabel('F150W magerr')


ax[1].plot(dat_1['mag_isocor'], dat_1['magerr_isocor'], 'o', ms=0.01, label='SEX')
ax[1].set_xlim([12.5, 32])
ax[1].set_ylim([0, 1])
ax[1].set_xlabel('F200W mag')
ax[1].set_ylabel('F200W magerr')

#=================================================================
lgnd0 = ax[0].legend()
lgnd0.legendHandles[0].set_markersize(6)
lgnd1 = ax[1].legend()
lgnd1.legendHandles[0].set_markersize(6)

# %%
psle0 = np.sqrt(fits.getheader(imglist[0], ext=1)['PIXAR_A2'])
psle1 = np.sqrt(fits.getheader(imglist[1], ext=1)['PIXAR_A2'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
stel0 = dat_0['cl']>0.8
stel1 = dat_1['cl']>0.8

# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax[0].plot(dat_0['fwhm']*psle0, dat_0['mag_iso'], 'o', ms=0.01, label='SEx')
ax[0].plot(dat_0['fwhm'][stel0]*psle0, dat_0['mag_iso'][stel0], 'o', color='red', ms=1, label='stel>0.8')
ax[0].set_xlim([0,1])
ax[0].set_ylim([32, 20])
ax[0].set_xlabel('F150W fwhm (arcsec)')
ax[0].set_ylabel('F150W mag_iso')
ax[0].axvline(0.06, ls='--', color='blue', label="FWHM=0.06")
ax[0].axvline(0.08, ls='--', color='green', label="FWHM=0.08")

ax[1].plot(dat_1['fwhm']*psle0, dat_1['mag_iso'], 'o', ms=0.01, label='SEX')
ax[1].plot(dat_1['fwhm'][stel1]*psle0, dat_1['mag_iso'][stel1], 'o', color='red', ms=1, label='stel>0.8')
ax[1].set_xlim([0,1])
ax[1].set_ylim([32, 20])
ax[1].set_xlabel('F200W fwhm (arcsec)')
ax[1].set_ylabel('F200W magisocor')
ax[1].axvline(0.06, ls='--', color='blue', label="FWHM=0.06")
ax[1].axvline(0.08, ls='--', color='green', label="FWHM=0.08")

#=================================================================
lgnd0 = ax[0].legend()
lgnd0.legendHandles[0].set_markersize(6)
lgnd0.legendHandles[1].set_markersize(6)

lgnd1 = ax[1].legend()
lgnd1.legendHandles[0].set_markersize(6)
lgnd1.legendHandles[1].set_markersize(6)
plt.show()
plt.tight_layout()

# %% [markdown]
# ### 2) Magnitude - stellarity (``CLASS_STAR``) digram

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,6))
mag_range = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)
# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax[0].plot(dat_0['mag_isocor'][mag_range], dat_0['cl'][mag_range], 'o', ms=1, label='SEx')
ax[0].set_xlim([12.5, 32])
ax[0].set_ylim([0.0, 1.0])
ax[0].set_xlabel('F105W mag')
ax[0].set_ylabel('Stellarity')
ax[0].axhline(0.4, 0, 1, color='red', ls='--', lw=1)
ax[0].axhline(0.8, 0, 1, color='red', ls='--', lw=1)


ax[1].plot(dat_1['mag_isocor'][mag_range], dat_1['cl'][mag_range], 'o', ms=1, label='SEX')
ax[1].set_xlim([12.5, 32])
ax[1].set_ylim([0, 1])
ax[1].set_xlabel('F160W mag')
ax[1].set_ylabel('Stellarity')
ax[1].axhline(0.4, 0, 1, color='red', ls='--', lw=1)
ax[1].axhline(0.8, 0, 1, color='red', ls='--', lw=1)

#=================================================================
lgnd0 = ax[0].legend()
lgnd0.legendHandles[0]._legmarker.set_markersize(6)
lgnd1 = ax[1].legend()
lgnd1.legendHandles[0]._legmarker.set_markersize(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5629/3335948844.py in <module>
#       1 fig, ax = plt.subplots(1, 2, figsize=(10,6))
# ----> 2 mag_range = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)
#       3 # magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
#       4 ax[0].plot(dat_0['mag_isocor'][mag_range], dat_0['cl'][mag_range], 'o', ms=1, label='SEx')
#       5 ax[0].set_xlim([12.5, 32])
#
# ValueError: operands could not be broadcast together with shapes (151469,) (997964,)

# %% [markdown]
# ### 3) CMDs of galaxies

# %%
# gal_cnd = ((dat_V['mag_isocor'] < 30.0) & (dat_V['magerr_isocor'] < 1) & (dat_I['mag_isocor'] < 30.0) & (dat_I['magerr_isocor'] < 1) & \
#           (dat_V['flxrad'] > 4.) & (dat_V['fwhm'] > 4.) & (dat_I['flxrad'] > 4.) & (dat_I['fwhm'] > 4.) & \
#           (dat_V['mag_isocor']-dat_I['mag_isocor'] > -5.0) & (dat_V['mag_isocor']-dat_I['mag_isocor'] < 5.0) & \
#           (dat_I['cl'] < 0.4)) 

fig, ax = plt.subplots(1, 1, figsize=(10,6))
galcnd = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)&(dat_0['flag']<4) #&(dat_0['flxrad'] > 4.) & (dat_0['fwhm'] > 4.) & (dat_1['fwhm'] > 4.) & (dat_1['merr'] < 0.5) & (dat_0['merr'] < 0.5)&(dat_1['cl'] < 0.4)


# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax.plot(dat_0['mag_isocor'][galcnd]-dat_1['mag_isocor'][galcnd], dat_1['mag_isocor'][galcnd], 'o', ms=0.5, label='SEx')
ax.set_xlim([-3, 3])
ax.set_ylim([30, 15])
ax.set_xlabel('F105W-F160W mag')
ax.set_ylabel('F160W mag')

#=================================================================
lgnd0 = ax.legend()
lgnd0.legendHandles[0]._legmarker.set_markersize(6)
