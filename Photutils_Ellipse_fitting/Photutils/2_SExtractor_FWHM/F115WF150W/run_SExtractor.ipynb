# %% [markdown]
# # 0. Importing Necessary Packages

# %%
# %set_env PATH=/root/anaconda3/bin:/root/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/root/.fzf./bin
# python vscode kernel restart 이후에도 base(python 3.7.6) 정상 작동하는 역할
# Out:
# env: PATH=/root/anaconda3/bin:/root/anaconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/root/.fzf./bin

# %%
# Printing the versions of packages
from importlib_metadata import version
for pkg in ['numpy', 'matplotlib', 'astropy', 'pandas']:
    print(pkg+": ver "+version(pkg))
# Out:
# numpy: ver 1.21.5
# matplotlib: ver 3.5.2
# astropy: ver 5.1
# pandas: ver 1.4.4

# %%
# matplotlib backend
# %matplotlib notebook

# importing necessary modules
import numpy as np
import glob, os
from matplotlib import pyplot as plt
from astropy.io import fits
import pandas as pd
#from acstools import acszpt
#from reproject import reproject_interp

# %%
plt.rcParams.update({'font.size': 25})
plt.rcParams.update({'font.weight': 'normal'})

plt.rcParams.update({'xtick.direction': 'in'})
plt.rcParams.update({'ytick.direction': 'in'})
plt.rcParams.update({'xtick.major.size': 10})
plt.rcParams.update({'xtick.minor.size': 6})
plt.rcParams.update({'ytick.major.size': 10})
plt.rcParams.update({'ytick.minor.size': 6})
plt.rcParams.update({'xtick.major.width': 1.6})
plt.rcParams.update({'xtick.minor.width': 1.6})
plt.rcParams.update({'ytick.major.width': 1.6})
plt.rcParams.update({'ytick.minor.width': 1.6})

plt.rcParams.update({'lines.linewidth': 2})
plt.rcParams.update({'axes.linewidth': 1.6})
plt.rcParams.update({'axes.labelpad': 4})
plt.rcParams.update({'xtick.major.pad': 7})
plt.rcParams.update({'image.origin':'lower'})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 1. Writing Input Files

# %% [markdown]
# ## 1) Image list

# %% [markdown]
# 105 150 200 중 105 150 먼저 쓰기 / 105가 ref

# %%
dir_img = "../../../img/align-image/" #"../FWHM/SExtractor/img_edit/"
band = ["F115W", "F150W"]
imglist_sub = sorted(glob.glob(dir_img+"*.fits"))
imglist_sub
imglist = [imglist_sub[0], imglist_sub[2]]
imglist
# Out:
# ['../../../img/align-image/jw01345-o002_t022_nircam_clear_f115w_aligned.fits',
#  '../../../img/align-image/jw01345-o002_t022_nircam_clear_f150w_aligned.fits']

# %% [markdown]
# ## 2) Configuration file

# %%
config_name = "config.txt"
os.system("sex -dd > "+config_name)
# Out:
# 0

# %% [markdown]
# ## 3) Output parameter file

# %%
param_name = "output.param"
f = open(param_name, "w")
f.write("X_IMAGE\n")    # Object position along x [pixel]
f.write("Y_IMAGE\n")    # Object position along y [pixel]
f.write("NUMBER\n")    # Object number
f.write("MAG_AUTO\n")    # Kron-like elliptical aperture magnitude [mag]
f.write("MAGERR_AUTO\n")    # RMS error for MAG_AUTO    [mag]
f.write("MAG_ISO\n") # Isophotal Magnitude
f.write("MAGERR_ISO\n") # Isophotal Magnitude Error
f.write("MAG_ISOCOR\n")
f.write("MAGERR_ISOCOR\n")
f.write("KRON_RADIUS\n")    # Kron apertures in units of A or B
f.write("BACKGROUND\n")    # Background at centroid position
f.write("ALPHA_J2000\n")    # Right ascension of object center (J2000)
f.write("DELTA_J2000\n")    # Declination of object center (J2000)
f.write("A_IMAGE\n")    # Along major axis
f.write("B_IMAGE\n")    # Along minor axis
f.write("THETA_IMAGE\n")    # Position angle
f.write("MU_MAX\n")    # Peak surface brightness above background
f.write("FLAGS\n")    # Extraction flags
f.write("FWHM_IMAGE\n")    # FWHM assuming a gaussian core
f.write("FLUX_RADIUS\n")    # Half-light radii
f.write("CLASS_STAR\n")    # Star/Galaxy classifier output
f.close()

# %% [markdown]
# ## 4) Determining input parameters

# %%
hdr_1 = fits.getheader(imglist[0], ext=1)
hdr_2 = fits.getheader(imglist[1], ext=1)

# %% [markdown]
# reference for zp in JWST docs <br>
# https://jwst-docs.stsci.edu/jwst-near-infrared-camera/nircam-performance/nircam-absolute-flux-calibration-and-zeropoints

# %% [markdown]
# use AB mag

# %% [markdown]
# ### 4-a) zeropoint calculation from imageheader value

# %%
# band = ["F105W", "F160W"]
cat_name = ["{}.cat".format(band[0]), "{}.cat".format(band[1])]
detect_minarea = 9  # DETECT_MINAREA = 5 (default)
detect_thresh = 0.3  #1이었음 # DETECT_THRESH = 1.5 (default)
saturated = 100.0  # SATUR_LEVEL = 100.0 (depending on the image!)
mag0 = [-6.10-2.5*np.log10(hdr_1['PIXAR_SR']),
        -6.10-2.5*np.log10(hdr_2['PIXAR_SR'])]
# mag0 = [26.268, 25.946]
# egain = [hdr_1['CCDGAIN']*hdr_1['EXPTIME'], hdr_2['CCDGAIN']*hdr_2['EXPTIME']]
# GAIN (effective gain) = gain*exptime (for c/s image) --> this parameter only affects the magnitude error value!
pixel_scale = 0.03  # arcsec/pixel
fwhm = [0.08, 0.08] #이번에 내가 쓰는 reduce img는 0.06arcsec/pixel   # For HST images, seeing FWHMs are typically 3 pixels (~ 0.09 arcsec).
# However, you can directly measure the FWHM value in your image using imexamine or etc.,
# because the FWHM value can also vary with image quality.
back_size = [64, 64]  # BACK_SIZE = 64 (default) --> 32 (revised)
# Smaller BACK_SIZE --> Can subtract more local background --> Can detect more sources
back_filtersize = [3, 3]

checkimg = ["{}_aper.fits".format(band[0]), "{}_aper.fits".format(band[1])]  # CHECKIMAGE_NAME (apertures)
refimg = imglist[0]


deblend_nthresh = [64, 64]
debelnd_mincont = [0.0001, 0.0001]

backphoto_type = "LOCAL"
backphoto_thick = 24

weight_image = ["../../../img/align-image/jw01345-o002_t022_nircam_clear_f115w_aligned.fits[4]","../../../img/align-image/jw01345-o002_t022_nircam_clear_f150w_aligned.fits[2]"]
refimg_rmsmap = weight_image[0]
weight_type = "MAP_WEIGHT" #MAP_RMS, MAP_WEIGHT
weight_gain = "Y"

filtering = "Y"
filter_name = "../config/default.conv"
# filter_thresh = [0.5, 1.0]

# %% [markdown]
# ### 4-b) PHOTFLAM / PHOTPLAM calculation by ACS zeropoint calculation system

# %%
''' 
dates = ['2011-07-16']
queries1 = []
queries2 = []
for date in dates:
    q1 = acszpt.Query(date=date, detector='WFC', filt='F606W')
    zpt_table = q1.fetch()
    # Each object has a zpt_table attribute, so we save the instance
    queries1.append(q1)
for date in dates:
    q2 = acszpt.Query(date=date, detector='WFC', filt='F814W')
    zpt_table = q2.fetch()
    # Each object has a zpt_table attribute, so we save the instance
    queries2.append(q2)


hdr_1["PHOTFLAM"]= q1.zpt_table['PHOTFLAM'][0].value
hdr_1["PHOTPLAM"]= q1.zpt_table['PHOTPLAM'][0].value
hdr_2["PHOTFLAM"]= q2.zpt_table['PHOTFLAM'][0].value
hdr_2["PHOTPLAM"]= q2.zpt_table['PHOTPLAM'][0].value


'''
# Out:
# ' \ndates = [\'2011-07-16\']\nqueries1 = []\nqueries2 = []\nfor date in dates:\n    q1 = acszpt.Query(date=date, detector=\'WFC\', filt=\'F606W\')\n    zpt_table = q1.fetch()\n    # Each object has a zpt_table attribute, so we save the instance\n    queries1.append(q1)\nfor date in dates:\n    q2 = acszpt.Query(date=date, detector=\'WFC\', filt=\'F814W\')\n    zpt_table = q2.fetch()\n    # Each object has a zpt_table attribute, so we save the instance\n    queries2.append(q2)\n\n\nhdr_1["PHOTFLAM"]= q1.zpt_table[\'PHOTFLAM\'][0].value\nhdr_1["PHOTPLAM"]= q1.zpt_table[\'PHOTPLAM\'][0].value\nhdr_2["PHOTFLAM"]= q2.zpt_table[\'PHOTFLAM\'][0].value\nhdr_2["PHOTPLAM"]= q2.zpt_table[\'PHOTPLAM\'][0].value\n\n\n'

# %% [markdown]
# ## 5) Shell script for SExtractor photometry

# %%
scr_name = "sephot.sh"
f = open(scr_name, "w")
for i in np.arange(len(band)):
        
    # Reference image 
    if (imglist[i] == refimg):
        txt = "sex "+imglist[i]+"[1]"+" -c config.txt -CATALOG_NAME "+cat_name[i]+" -PARAMETERS_NAME output.param "
        txt += f"-WEIGHT_GAIN {weight_gain:s} -WEIGHT_IMAGE {weight_image[i]:s} -WEIGHT_TYPE {weight_type:s} "

    # Non-reference image
    else:
        txt = "sex "+refimg+"[1]"+","+imglist[i]+"[1]"+" -c config.txt -CATALOG_NAME "+cat_name[i]+" -PARAMETERS_NAME output.param "
        txt += f"-WEIGHT_GAIN {weight_gain:s} -WEIGHT_IMAGE {refimg_rmsmap:s},{weight_image[i]:s} -WEIGHT_TYPE {weight_type:s} "

    #==== new added param
    txt += f"-BACK_FILTERSIZE {back_filtersize[i]:d} -DEBLEND_NTHRESH {deblend_nthresh[i]:d} -DEBLEND_MINCONT {debelnd_mincont[i]:.5f} -BACKPHOTO_TYPE {backphoto_type:s} -BACKPHOTO_THICK {backphoto_thick:d} "
    txt += f"-FILTER {filtering:s} -FILTER_NAME {filter_name:s} " #filtering part 제대로 적용안되는 듯 하면서 여전히 -FILTER_THRESH {filter_thresh[0]:.4f},{filter_thresh[1]:.4f} "
    #==== origin param
    txt += f"-DETECT_MINAREA {detect_minarea:d} -DETECT_THRESH {detect_thresh:.1f} "
    txt += f"-SATUR_LEVEL {saturated:.1f} "#txt += f"-FILTER_NAME /usr/share/sextractor/default.conv -SATUR_LEVEL {saturated:.1f} "
    txt += f"-MAG_ZEROPOINT {mag0[i]:.4f} -PIXEL_SCALE {pixel_scale:.2f} " #-GAIN {egain[i]:.2f} "
    txt += f"-SEEING_FWHM {fwhm[i]:.2f} -STARNNW_NAME ../config/default.nnw -BACK_SIZE {back_size[i]:d} "
    txt += "-CHECKIMAGE_TYPE APERTURES -CHECKIMAGE_NAME "+checkimg[i] # -CHECKIMAGE_TYPE APERTURES 
    txt += "\n"
    
    f.write(txt)
    
    
f.close()

# %% [markdown]
# # 2. Running SExtractor

# %% [markdown]
# use alignimage for dual-mode (same frame size need)

# %%
os.system("sh sephot.sh")
# Run this and see the terminal where the Jupyter Notebook is open!
# Out:
# >
# ----- SExtractor 2.25.0 started on 2023-02-15 at 11:30:23 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for jw01345-o002_t022_nircam_clear_f115w_aligned.fits
# ----- Measuring from: jw01345-o002_t022_nircam_clear_f115w_aligned.fits [1/9]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f115w_aligned.fits
# ----- Weighting from: jw01345-o002_t022_nircam_clear_f115w_aligned.fits [4/9]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 0.192349   RMS: 0.0075337  / Threshold: 0.00226011
# > Scanning image
# > Line:   25  Objects:      230 detected /        0 sextracted
# > Line:   50  Objects:     1238 detected /        0 sextracted
# > Line:   75  Objects:     2947 detected /        0 sextracted
# > Line:  100  Objects:     4170 detected /       37 sextracted
# > Line:  125  Objects:     5961 detected /     1263 sextracted
# > Line:  150  Objects:     8105 detected /     2720 sextracted
# > Line:  175  Objects:    10794 detected /     4619 sextracted
# > Line:  200  Objects:    13421 detected /     6445 sextracted
# > Line:  225  Objects:    15782 detected /     8055 sextracted
# > Line:  250  Objects:    18167 detected /     9751 sextracted
# > Line:  275  Objects:    20736 detected /    11525 sextracted
# > Line:  300  Objects:    22792 detected /    12931 sextracted
# > Line:  325  Objects:    25375 detected /    14780 sextracted
# > Line:  350  Objects:    28212 detected /    16836 sextracted
# > Line:  375  Objects:    30698 detected /    18631 sextracted
# > Line:  400  Objects:    33232 detected /    20395 sextracted
# > Line:  425  Objects:    35367 detected /    21895 sextracted
# > Line:  450  Objects:    37632 detected /    23452 sextracted
# > Line:  475  Objects:    40015 detected /    25130 sextracted
#
# > WARNING: Pixel stack overflow at position 7885,495
#
# > Line:  500  Objects:    42193 detected /    26738 sextracted
# > Line:  525  Objects:    45976 detected /    29549 sextracted
# > Line:  550  Objects:    48740 detected /    31456 sextracted
# > Line:  575  Objects:    51128 detected /    33146 sextracted
# > Line:  600  Objects:    54043 detected /    35349 sextracted
# > Line:  625  Objects:    56038 detected /    36725 sextracted
# > Line:  650  Objects:    59071 detected /    38984 sextracted
# > Line:  675  Objects:    61687 detected /    40827 sextracted
# > Line:  700  Objects:    63516 detected /    42086 sextracted
# > Line:  725  Objects:    66624 detected /    44372 sextracted
# > Line:  750  Objects:    69599 detected /    46645 sextracted
# > Line:  775  Objects:    71461 detected /    47951 sextracted
# > Line:  800  Objects:    74790 detected /    50388 sextracted
#
# > WARNING: Pixel stack overflow at position 7263,813
#
# > Line:  825  Objects:    77658 detected /    52435 sextracted
# > Line:  850  Objects:    80809 detected /    54664 sextracted
# > Line:  875  Objects:    83888 detected /    56918 sextracted
# > Line:  900  Objects:    86530 detected /    58821 sextracted
# > Line:  925  Objects:    89386 detected /    60704 sextracted
# > Line:  950  Objects:    91803 detected /    62374 sextracted
# > Line:  975  Objects:    94333 detected /    64127 sextracted
# > Line: 1000  Objects:    96847 detected /    65866 sextracted
# > Line: 1025  Objects:    99700 detected /    67880 sextracted
# > Line: 1050  Objects:   102815 detected /    70139 sextracted
# > Line: 1075  Objects:   106241 detected /    72672 sextracted
# > Line: 1100  Objects:   108689 detected /    74425 sextracted
# > Line: 1125  Objects:   111868 detected /    76633 sextracted
# > Line: 1150  Objects:   114312 detected /    78344 sextracted
# > Line: 1175  Objects:   116658 detected /    80012 sextracted
# > Line: 1200  Objects:   118882 detected /    81562 sextracted
# > Line: 1225  Objects:   122268 detected /    84041 sextracted
# > Line: 1250  Objects:   125826 detected /    86783 sextracted
# > Line: 1275  Objects:   129121 detected /    89416 sextracted
# > Line: 1300  Objects:   132072 detected /    91614 sextracted
# > Line: 1325  Objects:   134463 detected /    93307 sextracted
# > Line: 1350  Objects:   138219 detected /    96070 sextracted
# > Line: 1375  Objects:   140477 detected /    97704 sextracted
# > Line: 1400  Objects:   143165 detected /    99598 sextracted
# > Line: 1425  Objects:   146041 detected /   101672 sextracted
# > Line: 1450  Objects:   148762 detected /   103587 sextracted
# > Line: 1475  Objects:   151519 detected /   105626 sextracted
# > Line: 1500  Objects:   154112 detected /   107440 sextracted
# > Line: 1525  Objects:   157659 detected /   110179 sextracted
# > Line: 1550  Objects:   160348 detected /   112176 sextracted
# > Line: 1575  Objects:   162352 detected /   113601 sextracted
# > Line: 1600  Objects:   164487 detected /   115127 sextracted
# > Line: 1625  Objects:   167519 detected /   117302 sextracted
# > Line: 1650  Objects:   170745 detected /   119654 sextracted
# > Line: 1675  Objects:   174055 detected /   122114 sextracted
# > Line: 1700  Objects:   177553 detected /   124758 sextracted
# > Line: 1725  Objects:   180493 detected /   126829 sextracted
# > Line: 1750  Objects:   183362 detected /   128876 sextracted
# > Line: 1775  Objects:   185804 detected /   130598 sextracted
# > Line: 1800  Objects:   188747 detected /   132734 sextracted
# > Line: 1825  Objects:   191224 detected /   134515 sextracted
# > Line: 1850  Objects:   193596 detected /   136212 sextracted
# > Line: 1875  Objects:   196253 detected /   138089 sextracted
# > Line: 1900  Objects:   199572 detected /   140553 sextracted
# > Line: 1925  Objects:   202660 detected /   142843 sextracted
# > Line: 1950  Objects:   205238 detected /   144652 sextracted
# > Line: 1975  Objects:   208005 detected /   146607 sextracted
# > Line: 2000  Objects:   210034 detected /   148018 sextracted
# > Line: 2025  Objects:   212633 detected /   149867 sextracted
# > Line: 2050  Objects:   215109 detected /   151653 sextracted
# > Line: 2075  Objects:   218601 detected /   154339 sextracted
# > Line: 2100  Objects:   220917 detected /   155999 sextracted
# > Line: 2125  Objects:   222624 detected /   157246 sextracted
# > Line: 2150  Objects:   224364 detected /   158569 sextracted
# > Line: 2175  Objects:   225397 detected /   159273 sextracted
# > Line: 2200  Objects:   226654 detected /   160176 sextracted
# > Line: 2225  Objects:   228807 detected /   161840 sextracted
# > Line: 2250  Objects:   230111 detected /   162854 sextracted
# > Line: 2275  Objects:   231573 detected /   163938 sextracted
# > Line: 2300  Objects:   233903 detected /   165703 sextracted
# > Line: 2325  Objects:   235179 detected /   166555 sextracted
# > Line: 2350  Objects:   237456 detected /   168253 sextracted
# > Line: 2375  Objects:   239570 detected /   169672 sextracted
# > Line: 2400  Objects:   241937 detected /   171270 sextracted
# > Line: 2425  Objects:   244737 detected /   173287 sextracted
# > Line: 2450  Objects:   248436 detected /   176012 sextracted
# > Line: 2475  Objects:   251557 detected /   178164 sextracted
# > Line: 2500  Objects:   253964 detected /   179869 sextracted
# > Line: 2525  Objects:   256616 detected /   181801 sextracted
# > Line: 2550  Objects:   258469 detected /   183130 sextracted
# > Line: 2575  Objects:   261571 detected /   185342 sextracted
# > Line: 2600  Objects:   264799 detected /   187654 sextracted
# > Line: 2625  Objects:   267308 detected /   189408 sextracted
# > Line: 2650  Objects:   269926 detected /   191217 sextracted
# > Line: 2675  Objects:   273616 detected /   193821 sextracted
# > Line: 2700  Objects:   276144 detected /   195593 sextracted
# > Line: 2725  Objects:   278837 detected /   197461 sextracted
# > Line: 2750  Objects:   281668 detected /   199479 sextracted
# > Line: 2775  Objects:   284813 detected /   201715 sextracted
# > Line: 2800  Objects:   287717 detected /   203724 sextracted
# > Line: 2825  Objects:   290563 detected /   205662 sextracted
# > Line: 2850  Objects:   292686 detected /   207086 sextracted
# > Line: 2875  Objects:   294911 detected /   208643 sextracted
# > Line: 2900  Objects:   297948 detected /   210739 sextracted
# > Line: 2925  Objects:   301087 detected /   212941 sextracted
# > Line: 2950  Objects:   303634 detected /   214680 sextracted
# > Line: 2975  Objects:   307436 detected /   217352 sextracted
# > Line: 3000  Objects:   309879 detected /   218963 sextracted
# > Line: 3025  Objects:   312496 detected /   220776 sextracted
# > Line: 3050  Objects:   315148 detected /   222596 sextracted
# > Line: 3075  Objects:   318486 detected /   225008 sextracted
# > Line: 3100  Objects:   320604 detected /   226484 sextracted
# > Line: 3125  Objects:   323585 detected /   228555 sextracted
# > Line: 3150  Objects:   326364 detected /   230492 sextracted
# > Line: 3175  Objects:   328821 detected /   232205 sextracted
# > Line: 3200  Objects:   330983 detected /   233618 sextracted
# > Line: 3225  Objects:   333529 detected /   235351 sextracted
# > Line: 3250  Objects:   336390 detected /   237370 sextracted
# > Line: 3275  Objects:   338797 detected /   239097 sextracted
# > Line: 3300  Objects:   341255 detected /   240851 sextracted
# > Line: 3325  Objects:   344218 detected /   242936 sextracted
# > Line: 3350  Objects:   346775 detected /   244671 sextracted
# > Line: 3375  Objects:   349628 detected /   246689 sextracted
# > Line: 3400  Objects:   352304 detected /   248589 sextracted
# > Line: 3425  Objects:   354812 detected /   250304 sextracted
# > Line: 3450  Objects:   357536 detected /   252110 sextracted
# > Line: 3475  Objects:   360071 detected /   253842 sextracted
# > Line: 3500  Objects:   362277 detected /   255360 sextracted
# > Line: 3525  Objects:   365634 detected /   257720 sextracted
# > Line: 3550  Objects:   368215 detected /   259519 sextracted
# > Line: 3575  Objects:   371397 detected /   261758 sextracted
# > Line: 3600  Objects:   374078 detected /   263660 sextracted
# > Line: 3625  Objects:   376841 detected /   265510 sextracted
# > Line: 3650  Objects:   379701 detected /   267426 sextracted
# > Line: 3675  Objects:   382003 detected /   268965 sextracted
# > Line: 3700  Objects:   384526 detected /   270697 sextracted
# > Line: 3725  Objects:   386931 detected /   272354 sextracted
# > Line: 3750  Objects:   389044 detected /   273762 sextracted
# > Line: 3775  Objects:   391853 detected /   275682 sextracted
# > Line: 3800  Objects:   395317 detected /   278176 sextracted
# > Line: 3825  Objects:   398016 detected /   280053 sextracted
# > Line: 3850  Objects:   400248 detected /   281551 sextracted
# > Line: 3875  Objects:   403717 detected /   284229 sextracted
# > Line: 3900  Objects:   406181 detected /   285941 sextracted
# > Line: 3925  Objects:   409439 detected /   288244 sextracted
# > Line: 3950  Objects:   411833 detected /   289850 sextracted
# > Line: 3975  Objects:   414650 detected /   291787 sextracted
# > Line: 4000  Objects:   417016 detected /   293368 sextracted
# > Line: 4025  Objects:   419392 detected /   294955 sextracted
# > Line: 4050  Objects:   422401 detected /   297018 sextracted
# > Line: 4075  Objects:   424731 detected /   298626 sextracted
# > Line: 4100  Objects:   427371 detected /   300473 sextracted
# > Line: 4125  Objects:   430246 detected /   302455 sextracted
# > Line: 4150  Objects:   432807 detected /   304311 sextracted
# > Line: 4175  Objects:   435188 detected /   305939 sextracted
# > Line: 4200  Objects:   437969 detected /   307870 sextracted
# > Line: 4225  Objects:   440255 detected /   309455 sextracted
# > Line: 4250  Objects:   443031 detected /   311447 sextracted
# > Line: 4275  Objects:   445384 detected /   313158 sextracted
# > Line: 4300  Objects:   448255 detected /   315366 sextracted
# > Line: 4325  Objects:   449249 detected /   316047 sextracted
# > Line: 4350  Objects:   449622 detected /   316319 sextracted
# > Line: 4375  Objects:   450288 detected /   316815 sextracted
# > Line: 4388  Objects:   452399 detected /   318800 sextracted
# > Line: 4388  Objects:   452399 detected /   319200 sextracted
# > Line: 4388  Objects:   452399 detected /   319600 sextracted
# > Line: 4388  Objects:   452399 detected /   320000 sextracted
# > Line: 4388  Objects:   452399 detected /   320400 sextracted
# > Line: 4388  Objects:   452399 detected /   320800 sextracted
# > Line: 4388  Objects:   452399 detected /   321200 sextracted
#       Objects: detected 452399   / sextracted 321539
#
# > Closing files
# >
# > All done (in 157.6 s: 27.8 lines/s , 2040.2 detections/s)
# >
# ----- SExtractor 2.25.0 started on 2023-02-15 at 11:33:01 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for jw01345-o002_t022_nircam_clear_f115w_aligned.fits
# ----- Detecting from: jw01345-o002_t022_nircam_clear_f115w_aligned.fits [1/9]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f150w_aligned.fits
# ----- Measuring from: jw01345-o002_t022_nircam_clear_f150w_aligned.fits [1/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f150w_aligned.fits
# ----- Weighting from: jw01345-o002_t022_nircam_clear_f150w_aligned.fits [2/2]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# > Looking for jw01345-o002_t022_nircam_clear_f115w_aligned.fits
# ----- Weighting from: jw01345-o002_t022_nircam_clear_f115w_aligned.fits [4/9]
#       "Unnamed" / no ext. header / 9929x4388 / 32 bits (floats)
# Measurement image:> Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M)   Background: 0.197915   RMS: 0.00761708 / Threshold: 0.0114256
# Detection image: > Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (D)   Background: 0.192349   RMS: 0.0075337  / Threshold: 0.00226011
# > Scanning image
# > Line:   25  Objects:      230 detected /        0 sextracted
# > Line:   50  Objects:     1238 detected /        0 sextracted
# > Line:   75  Objects:     2947 detected /        0 sextracted
# > Line:  100  Objects:     4170 detected /       37 sextracted
# > Line:  125  Objects:     5961 detected /     1263 sextracted
# > Line:  150  Objects:     8105 detected /     2720 sextracted
# > Line:  175  Objects:    10794 detected /     4619 sextracted
# > Line:  200  Objects:    13421 detected /     6445 sextracted
# > Line:  225  Objects:    15782 detected /     8055 sextracted
# > Line:  250  Objects:    18167 detected /     9751 sextracted
# > Line:  275  Objects:    20736 detected /    11525 sextracted
# > Line:  300  Objects:    22792 detected /    12931 sextracted
# > Line:  325  Objects:    25375 detected /    14780 sextracted
# > Line:  350  Objects:    28212 detected /    16836 sextracted
# > Line:  375  Objects:    30698 detected /    18631 sextracted
# > Line:  400  Objects:    33232 detected /    20395 sextracted
# > Line:  425  Objects:    35367 detected /    21895 sextracted
# > Line:  450  Objects:    37632 detected /    23452 sextracted
# > Line:  475  Objects:    40015 detected /    25130 sextracted
#
# > WARNING: Pixel stack overflow at position 7885,495
#
# > Line:  500  Objects:    42193 detected /    26738 sextracted
# > Line:  525  Objects:    45976 detected /    29549 sextracted
# > Line:  550  Objects:    48740 detected /    31456 sextracted
# > Line:  575  Objects:    51128 detected /    33146 sextracted
# > Line:  600  Objects:    54043 detected /    35349 sextracted
# > Line:  625  Objects:    56038 detected /    36725 sextracted
# > Line:  650  Objects:    59071 detected /    38984 sextracted
# > Line:  675  Objects:    61687 detected /    40827 sextracted
# > Line:  700  Objects:    63516 detected /    42086 sextracted
# > Line:  725  Objects:    66624 detected /    44372 sextracted
# > Line:  750  Objects:    69599 detected /    46645 sextracted
# > Line:  775  Objects:    71461 detected /    47951 sextracted
# > Line:  800  Objects:    74790 detected /    50388 sextracted
#
# > WARNING: Pixel stack overflow at position 7263,813
#
# > Line:  825  Objects:    77658 detected /    52435 sextracted
# > Line:  850  Objects:    80809 detected /    54664 sextracted
# > Line:  875  Objects:    83888 detected /    56918 sextracted
# > Line:  900  Objects:    86530 detected /    58821 sextracted
# > Line:  925  Objects:    89386 detected /    60704 sextracted
# > Line:  950  Objects:    91803 detected /    62374 sextracted
# > Line:  975  Objects:    94333 detected /    64127 sextracted
# > Line: 1000  Objects:    96847 detected /    65866 sextracted
# > Line: 1025  Objects:    99700 detected /    67880 sextracted
# > Line: 1050  Objects:   102815 detected /    70139 sextracted
# > Line: 1075  Objects:   106241 detected /    72672 sextracted
# > Line: 1100  Objects:   108689 detected /    74425 sextracted
# > Line: 1125  Objects:   111868 detected /    76633 sextracted
# > Line: 1150  Objects:   114312 detected /    78344 sextracted
# > Line: 1175  Objects:   116658 detected /    80012 sextracted
# > Line: 1200  Objects:   118882 detected /    81562 sextracted
# > Line: 1225  Objects:   122268 detected /    84041 sextracted
# > Line: 1250  Objects:   125826 detected /    86783 sextracted
# > Line: 1275  Objects:   129121 detected /    89416 sextracted
# > Line: 1300  Objects:   132072 detected /    91614 sextracted
# > Line: 1325  Objects:   134463 detected /    93307 sextracted
# > Line: 1350  Objects:   138219 detected /    96070 sextracted
# > Line: 1375  Objects:   140477 detected /    97704 sextracted
# > Line: 1400  Objects:   143165 detected /    99598 sextracted
# > Line: 1425  Objects:   146041 detected /   101672 sextracted
# > Line: 1450  Objects:   148762 detected /   103587 sextracted
# > Line: 1475  Objects:   151519 detected /   105626 sextracted
# > Line: 1500  Objects:   154112 detected /   107440 sextracted
# > Line: 1525  Objects:   157659 detected /   110179 sextracted
# > Line: 1550  Objects:   160348 detected /   112176 sextracted
# > Line: 1575  Objects:   162352 detected /   113601 sextracted
# > Line: 1600  Objects:   164487 detected /   115127 sextracted
# > Line: 1625  Objects:   167519 detected /   117302 sextracted
# > Line: 1650  Objects:   170745 detected /   119654 sextracted
# > Line: 1675  Objects:   174055 detected /   122114 sextracted
# > Line: 1700  Objects:   177553 detected /   124758 sextracted
# > Line: 1725  Objects:   180493 detected /   126829 sextracted
# > Line: 1750  Objects:   183362 detected /   128876 sextracted
# > Line: 1775  Objects:   185804 detected /   130598 sextracted
# > Line: 1800  Objects:   188747 detected /   132734 sextracted
# > Line: 1825  Objects:   191224 detected /   134515 sextracted
# > Line: 1850  Objects:   193596 detected /   136212 sextracted
# > Line: 1875  Objects:   196253 detected /   138089 sextracted
# > Line: 1900  Objects:   199572 detected /   140553 sextracted
# > Line: 1925  Objects:   202660 detected /   142843 sextracted
# > Line: 1950  Objects:   205238 detected /   144652 sextracted
# > Line: 1975  Objects:   208005 detected /   146607 sextracted
# > Line: 2000  Objects:   210034 detected /   148018 sextracted
# > Line: 2025  Objects:   212633 detected /   149867 sextracted
# > Line: 2050  Objects:   215109 detected /   151653 sextracted
# > Line: 2075  Objects:   218601 detected /   154339 sextracted
# > Line: 2100  Objects:   220917 detected /   155999 sextracted
# > Line: 2125  Objects:   222624 detected /   157246 sextracted
# > Line: 2150  Objects:   224364 detected /   158569 sextracted
# > Line: 2175  Objects:   225397 detected /   159273 sextracted
# > Line: 2200  Objects:   226654 detected /   160176 sextracted
# > Line: 2225  Objects:   228807 detected /   161840 sextracted
# > Line: 2250  Objects:   230111 detected /   162854 sextracted
# > Line: 2275  Objects:   231573 detected /   163938 sextracted
# > Line: 2300  Objects:   233903 detected /   165703 sextracted
# > Line: 2325  Objects:   235179 detected /   166555 sextracted
# > Line: 2350  Objects:   237456 detected /   168253 sextracted
# > Line: 2375  Objects:   239570 detected /   169672 sextracted
# > Line: 2400  Objects:   241937 detected /   171270 sextracted
# > Line: 2425  Objects:   244737 detected /   173287 sextracted
# > Line: 2450  Objects:   248436 detected /   176012 sextracted
# > Line: 2475  Objects:   251557 detected /   178164 sextracted
# > Line: 2500  Objects:   253964 detected /   179869 sextracted
# > Line: 2525  Objects:   256616 detected /   181801 sextracted
# > Line: 2550  Objects:   258469 detected /   183130 sextracted
# > Line: 2575  Objects:   261571 detected /   185342 sextracted
# > Line: 2600  Objects:   264799 detected /   187654 sextracted
# > Line: 2625  Objects:   267308 detected /   189408 sextracted
# > Line: 2650  Objects:   269926 detected /   191217 sextracted
# > Line: 2675  Objects:   273616 detected /   193821 sextracted
# > Line: 2700  Objects:   276144 detected /   195593 sextracted
# > Line: 2725  Objects:   278837 detected /   197461 sextracted
# > Line: 2750  Objects:   281668 detected /   199479 sextracted
# > Line: 2775  Objects:   284813 detected /   201715 sextracted
# > Line: 2800  Objects:   287717 detected /   203724 sextracted
# > Line: 2825  Objects:   290563 detected /   205662 sextracted
# > Line: 2850  Objects:   292686 detected /   207086 sextracted
# > Line: 2875  Objects:   294911 detected /   208643 sextracted
# > Line: 2900  Objects:   297948 detected /   210739 sextracted
# > Line: 2925  Objects:   301087 detected /   212941 sextracted
# > Line: 2950  Objects:   303634 detected /   214680 sextracted
# > Line: 2975  Objects:   307436 detected /   217352 sextracted
# > Line: 3000  Objects:   309879 detected /   218963 sextracted
# > Line: 3025  Objects:   312496 detected /   220776 sextracted
# > Line: 3050  Objects:   315148 detected /   222596 sextracted
# > Line: 3075  Objects:   318486 detected /   225008 sextracted
# > Line: 3100  Objects:   320604 detected /   226484 sextracted
# > Line: 3125  Objects:   323585 detected /   228555 sextracted
# > Line: 3150  Objects:   326364 detected /   230492 sextracted
# > Line: 3175  Objects:   328821 detected /   232205 sextracted
# > Line: 3200  Objects:   330983 detected /   233618 sextracted
# > Line: 3225  Objects:   333529 detected /   235351 sextracted
# > Line: 3250  Objects:   336390 detected /   237370 sextracted
# > Line: 3275  Objects:   338797 detected /   239097 sextracted
# > Line: 3300  Objects:   341255 detected /   240851 sextracted
# > Line: 3325  Objects:   344218 detected /   242936 sextracted
# > Line: 3350  Objects:   346775 detected /   244671 sextracted
# > Line: 3375  Objects:   349628 detected /   246689 sextracted
# > Line: 3400  Objects:   352304 detected /   248589 sextracted
# > Line: 3425  Objects:   354812 detected /   250304 sextracted
# > Line: 3450  Objects:   357536 detected /   252110 sextracted
# > Line: 3475  Objects:   360071 detected /   253842 sextracted
# > Line: 3500  Objects:   362277 detected /   255360 sextracted
# > Line: 3525  Objects:   365634 detected /   257720 sextracted
# > Line: 3550  Objects:   368215 detected /   259519 sextracted
# > Line: 3575  Objects:   371397 detected /   261758 sextracted
# > Line: 3600  Objects:   374078 detected /   263660 sextracted
# > Line: 3625  Objects:   376841 detected /   265510 sextracted
# > Line: 3650  Objects:   379701 detected /   267426 sextracted
# > Line: 3675  Objects:   382003 detected /   268965 sextracted
# > Line: 3700  Objects:   384526 detected /   270697 sextracted
# > Line: 3725  Objects:   386931 detected /   272354 sextracted
# > Line: 3750  Objects:   389044 detected /   273762 sextracted
# > Line: 3775  Objects:   391853 detected /   275682 sextracted
# > Line: 3800  Objects:   395317 detected /   278176 sextracted
# > Line: 3825  Objects:   398016 detected /   280053 sextracted
# > Line: 3850  Objects:   400248 detected /   281551 sextracted
# > Line: 3875  Objects:   403717 detected /   284229 sextracted
# > Line: 3900  Objects:   406181 detected /   285941 sextracted
# > Line: 3925  Objects:   409439 detected /   288244 sextracted
# > Line: 3950  Objects:   411833 detected /   289850 sextracted
# > Line: 3975  Objects:   414650 detected /   291787 sextracted
# > Line: 4000  Objects:   417016 detected /   293368 sextracted
# > Line: 4025  Objects:   419392 detected /   294955 sextracted
# > Line: 4050  Objects:   422401 detected /   297018 sextracted
# > Line: 4075  Objects:   424731 detected /   298626 sextracted
# > Line: 4100  Objects:   427371 detected /   300473 sextracted
# > Line: 4125  Objects:   430246 detected /   302455 sextracted
# > Line: 4150  Objects:   432807 detected /   304311 sextracted
# > Line: 4175  Objects:   435188 detected /   305939 sextracted
# > Line: 4200  Objects:   437969 detected /   307870 sextracted
# > Line: 4225  Objects:   440255 detected /   309455 sextracted
# > Line: 4250  Objects:   443031 detected /   311447 sextracted
# > Line: 4275  Objects:   445384 detected /   313158 sextracted
# > Line: 4300  Objects:   448255 detected /   315366 sextracted
# > Line: 4325  Objects:   449249 detected /   316047 sextracted
# > Line: 4350  Objects:   449622 detected /   316319 sextracted
# > Line: 4375  Objects:   450288 detected /   316815 sextracted
# > Line: 4388  Objects:   452399 detected /   318800 sextracted
# > Line: 4388  Objects:   452399 detected /   319200 sextracted
# > Line: 4388  Objects:   452399 detected /   319600 sextracted
# > Line: 4388  Objects:   452399 detected /   320000 sextracted
# > Line: 4388  Objects:   452399 detected /   320400 sextracted
# > Line: 4388  Objects:   452399 detected /   320800 sextracted
# > Line: 4388  Objects:   452399 detected /   321200 sextracted
#       Objects: detected 452399   / sextracted 321539
#
# > Closing files
# >
# > All done (in 160.6 s: 27.3 lines/s , 2001.9 detections/s)
# 0

# %% [markdown]
# # 3. Reading the Data

# %%
# exec("dat_{} = np.genfromtxt(cat_name[0], dtype=None, encoding='ascii', names=colnames)".format(band[0]))
# exec("dat_{} = np.genfromtxt(cat_nam"e[1], dtype=None, encoding='ascii', names=colnames)".format(band[1]))
# Code that makes data name containts wave band
colnames = ['x','y','num','mag_auto','magerr_auto','mag_iso','magerr_iso','mag_isocor','magerr_isocor','kron','backgr','ra','dec', 
            'a','b','theta','mu0','flag','fwhm','flxrad','cl']
dat_0 = np.genfromtxt(cat_name[0], dtype=None, encoding='ascii', names=colnames)
dat_1 = np.genfromtxt(cat_name[1], dtype=None, encoding='ascii', names=colnames)

# %%
pd.DataFrame(dat_0).head(5)
# Out:
#            x        y  num  mag_auto  magerr_auto  mag_iso  magerr_iso  \
# 0  2504.1592   6.4444    1   28.4183       0.3559  28.6392      0.2275
# 1  3097.7036   7.6150    2   28.4735       0.3096  29.0854      0.2176
# 2  3629.5940  11.4768    3   30.1255       0.8257  29.6185      0.3220
# 3  1687.1289  11.3116    4   29.5606       1.2865  29.7335      0.4835
# 4  2694.6523  12.5744    5   30.4559       0.7535  30.7423      0.5646
#
#    mag_isocor  magerr_isocor  kron  ...          ra        dec      a      b  \
# 0     28.5223         0.2088   3.5  ...  214.848097  52.910154  2.351  0.767
# 1     29.0181         0.2068   3.5  ...  214.853642  52.914089  1.257  0.802
# 2     29.4573         0.2888   3.5  ...  214.858644  52.917600  1.259  0.493
# 3     29.5328         0.4223   3.5  ...  214.840536  52.904699  2.142  0.499
# 4     30.4371         0.4721   3.5  ...  214.849940  52.911384  1.293  0.492
#
#    theta      mu0  flag  fwhm  flxrad     cl
# 0   2.43  23.5594    19  8.03   2.077  0.877
# 1  17.58  23.1323    19  5.99   1.779  0.726
# 2   3.90  23.9976     0  4.68   1.255  0.636
# 3   2.57  23.7890    19  6.17   1.280  0.665
# 4   2.50  24.5621     0  0.53   1.515  0.485
#
# [5 rows x 21 columns]

# %%
pd.DataFrame(dat_1).head(5)
# Out:
#            x        y  num  mag_auto  magerr_auto  mag_iso  magerr_iso  \
# 0  2504.1592   6.4444    1   30.8175       1.4913  99.0000     99.0000
# 1  3097.7036   7.6150    2   28.2250       0.1025  29.8021      0.2424
# 2  3629.5940  11.4768    3   99.0000      99.0000  34.5683     20.4057
# 3  1687.1289  11.3116    4   29.7911       0.4973  31.3834      1.0475
# 4  2694.6523  12.5744    5   31.7010       1.9863  99.0000     99.0000
#
#    mag_isocor  magerr_isocor  kron  ...          ra        dec      a      b  \
# 0     99.0000        99.0000   3.5  ...  214.846892  52.910238  2.351  0.767
# 1     29.6116         0.2201   3.5  ...  214.852512  52.914143  1.257  0.802
# 2     31.3727         2.1195   0.0  ...  214.857581  52.917626  1.259  0.493
# 3     28.1878         0.1127   3.5  ...  214.839227  52.904825  2.142  0.499
# 4     99.0000        99.0000   3.5  ...  214.848758  52.911458  1.293  0.492
#
#    theta      mu0  flag  fwhm  flxrad     cl
# 0   2.43  24.5589    19  8.03  13.124  0.538
# 1  17.58  24.3635    19  5.99   2.533  0.522
# 2   3.90  24.8717     0  0.00 -11.069  0.498
# 3   2.57  23.9559    19  6.17   1.394  0.605
# 4   2.50  24.9665     0  0.00   2.194  0.462
#
# [5 rows x 21 columns]

# %% [markdown]
# # 5. Plotting the Figures

# %%
# %matplotlib inline

# %% [markdown]
# ### 0) RA/DEC

# %%
fig, axs = plt.subplots(1, 1, figsize=(5,5))
axs.plot(dat_0['ra'], dat_0['dec'], 'o', ms=0.5, label = 'SEx')
axs.set_xlabel("ra")
axs.set_ylabel("Dec")
# change legend markersize
lgnd = axs.legend()
lgnd.legendHandles[0].set_markersize(6)

# %% [markdown]
# ### 1) Mag-MagErr Plot

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,4))
# mag_range = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)

# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax[0].plot(dat_0['mag_isocor'], dat_0['magerr_isocor'], 'o', ms=0.01, label='SEx')
ax[0].set_xlim([12.5, 32])
ax[0].set_ylim([0.0, 1.0])
ax[0].set_xlabel('F115W mag')
ax[0].set_ylabel('F115W magerr')


ax[1].plot(dat_1['mag_isocor'], dat_1['magerr_isocor'], 'o', ms=0.01, label='SEX')
ax[1].set_xlim([12.5, 32])
ax[1].set_ylim([0, 1])
ax[1].set_xlabel('F150W mag')
ax[1].set_ylabel('F150W magerr')

#=================================================================
lgnd0 = ax[0].legend()
lgnd0.legendHandles[0].set_markersize(6)
lgnd1 = ax[1].legend()
lgnd1.legendHandles[0].set_markersize(6)

# %%
psle0 = np.sqrt(fits.getheader(imglist[0], ext=1)['PIXAR_A2'])
psle1 = np.sqrt(fits.getheader(imglist[1], ext=1)['PIXAR_A2'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,6))
stel0 = dat_0['cl']>0.8
stel1 = dat_1['cl']>0.8

# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax[0].plot(dat_0['fwhm']*psle0, dat_0['mag_iso'], 'o', ms=0.1, label='SEx')
ax[0].plot(dat_0['fwhm'][stel0]*psle0, dat_0['mag_iso'][stel0], 'o', color='red', ms=1, label='stel>0.8')
ax[0].set_xlim([0,1])
ax[0].set_ylim([32, 20])
ax[0].set_xlabel('F115W fwhm (arcsec)')
ax[0].set_ylabel('F115W mag_iso')
ax[0].axvline(0.06, ls='--', color='blue', label="FWHM=0.06")
ax[0].axvline(0.08, ls='--', color='green', label="FWHM=0.08")

ax[1].plot(dat_1['fwhm']*psle0, dat_1['mag_iso'], 'o', ms=0.1, label='SEX')
ax[1].plot(dat_1['fwhm'][stel1]*psle0, dat_1['mag_iso'][stel1], 'o', color='red', ms=1, label='stel>0.8')
ax[1].set_xlim([0,1])
ax[1].set_ylim([32, 20])
ax[1].set_xlabel('F150W fwhm (arcsec)')
ax[1].set_ylabel('F150W magisocor')
ax[1].axvline(0.06, ls='--', color='blue', label="FWHM=0.06")
ax[1].axvline(0.08, ls='--', color='green', label="FWHM=0.08")

#=================================================================
lgnd0 = ax[0].legend()
lgnd0.legendHandles[0].set_markersize(6)
lgnd0.legendHandles[1].set_markersize(6)

lgnd1 = ax[1].legend()
lgnd1.legendHandles[0].set_markersize(6)
lgnd1.legendHandles[1].set_markersize(6)
plt.show()
plt.tight_layout()

# %% [markdown]
# ### 2) Magnitude - stellarity (``CLASS_STAR``) digram

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,6))
mag_range = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)
# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax[0].plot(dat_0['mag_isocor'][mag_range], dat_0['cl'][mag_range], 'o', ms=1, label='SEx')
ax[0].set_xlim([12.5, 32])
ax[0].set_ylim([0.0, 1.0])
ax[0].set_xlabel('F105W mag')
ax[0].set_ylabel('Stellarity')
ax[0].axhline(0.4, 0, 1, color='red', ls='--', lw=1)
ax[0].axhline(0.8, 0, 1, color='red', ls='--', lw=1)


ax[1].plot(dat_1['mag_isocor'][mag_range], dat_1['cl'][mag_range], 'o', ms=1, label='SEX')
ax[1].set_xlim([12.5, 32])
ax[1].set_ylim([0, 1])
ax[1].set_xlabel('F160W mag')
ax[1].set_ylabel('Stellarity')
ax[1].axhline(0.4, 0, 1, color='red', ls='--', lw=1)
ax[1].axhline(0.8, 0, 1, color='red', ls='--', lw=1)

#=================================================================
lgnd0 = ax[0].legend()
lgnd0.legendHandles[0]._legmarker.set_markersize(6)
lgnd1 = ax[1].legend()
lgnd1.legendHandles[0]._legmarker.set_markersize(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5629/3335948844.py in <module>
#       1 fig, ax = plt.subplots(1, 2, figsize=(10,6))
# ----> 2 mag_range = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)
#       3 # magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
#       4 ax[0].plot(dat_0['mag_isocor'][mag_range], dat_0['cl'][mag_range], 'o', ms=1, label='SEx')
#       5 ax[0].set_xlim([12.5, 32])
#
# ValueError: operands could not be broadcast together with shapes (151469,) (997964,)

# %% [markdown]
# ### 3) CMDs of galaxies

# %%
# gal_cnd = ((dat_V['mag_isocor'] < 30.0) & (dat_V['magerr_isocor'] < 1) & (dat_I['mag_isocor'] < 30.0) & (dat_I['magerr_isocor'] < 1) & \
#           (dat_V['flxrad'] > 4.) & (dat_V['fwhm'] > 4.) & (dat_I['flxrad'] > 4.) & (dat_I['fwhm'] > 4.) & \
#           (dat_V['mag_isocor']-dat_I['mag_isocor'] > -5.0) & (dat_V['mag_isocor']-dat_I['mag_isocor'] < 5.0) & \
#           (dat_I['cl'] < 0.4)) 

fig, ax = plt.subplots(1, 1, figsize=(10,6))
galcnd = (dat_0['mag_isocor'] < 99.0)&(dat_1['mag_isocor']<99.0)&(dat_0['flag']<4) #&(dat_0['flxrad'] > 4.) & (dat_0['fwhm'] > 4.) & (dat_1['fwhm'] > 4.) & (dat_1['merr'] < 0.5) & (dat_0['merr'] < 0.5)&(dat_1['cl'] < 0.4)


# magnitude of 99.0 means the source not detected in the 606-band image but detected in the 814-band image.
ax.plot(dat_0['mag_isocor'][galcnd]-dat_1['mag_isocor'][galcnd], dat_1['mag_isocor'][galcnd], 'o', ms=0.5, label='SEx')
ax.set_xlim([-3, 3])
ax.set_ylim([30, 15])
ax.set_xlabel('F105W-F160W mag')
ax.set_ylabel('F160W mag')

#=================================================================
lgnd0 = ax.legend()
lgnd0.legendHandles[0]._legmarker.set_markersize(6)
